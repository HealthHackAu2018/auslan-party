# %% [markdown]
# # Dataset preparation

# %%
from pathlib import Path
import json
import requests

from shutil import copyfile
from tqdm import tqdm_notebook
import xmltodict

# %% [markdown]
# ## Convert RectLabel format

# %%
alphabet = list('abcdefghijklmnopqrstuvwxyz') + ['na']

# %%
alphabet[:10]
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
atoi = {l: c for c, l in enumerate(alphabet)}

# %%
atoi['na']
# Out:
# 26

# %%
PATH = Path('../data/')

# %%
YOLO_OUTPATH = PATH/'yolo'
YOLO_OUTPATH.mkdir(exist_ok=True)

# %%
VID_IDS = ['33qU9tQlEa4', '6iP3g_qSf28', 'EBH3wdRtZyg', 'pAz_mIjHglw']

# %%
# keep_ids = set(['h', 'e', 'a', 'l', 't', 'h', 'h', 'a', 'c', 'k'])

# %%
for vid_id in tqdm_notebook(VID_IDS):
    VID_PATH = PATH/'annotations'/vid_id
    for item in VID_PATH.iterdir():
        with open(item) as fd:
            doc = xmltodict.parse(fd.read())
            
        if 'object' not in doc['annotation']:
            continue
            
        class_name = doc['annotation']['object']['name']
            
        img_width = int(doc['annotation']['size']['width'])
        img_height = int(doc['annotation']['size']['height'])
        
        bnd_box = doc['annotation']['object']['bndbox']
        
        x_min, y_min, x_max, y_max = (
            int(bnd_box['xmin']), int(bnd_box['ymin']), int(bnd_box['xmax']), int(bnd_box['ymax']))
        width = x_max - x_min
        height = y_max - y_min

        class_id = atoi[class_name]
        
        video_file_id = str(item).split('/')[-1].split('.')[-2]
        copyfile(PATH/f'images/{vid_id}/{video_file_id}.jpg', YOLO_OUTPATH/f'{video_file_id}.jpg')
        with open(YOLO_OUTPATH/f'{video_file_id}.txt', 'w') as fh:
            fh.write(f'{class_id} {x_min / img_width} {y_min / img_height} {width / img_width} {height / img_height}')
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))

# %% [markdown]
# ## Convert DataTurks format

# %%
JSON_VID_IDS = ['ZO8Npgp4xvw', '_5NbYyUlcHU']

# %%
for vid_id in tqdm_notebook(JSON_VID_IDS):
    for line in open(PATH/'annotations'/f'{vid_id}.json'):
        line = json.loads(line)
        anno = line['annotation'][0]

        xmin = min(
            anno['points'][0][0], anno['points'][1][0], anno['points'][2][0], anno['points'][3][0])

        ymin = min(
            anno['points'][0][1], anno['points'][1][1],
            anno['points'][2][1], anno['points'][3][1])

        xmax = max(
            anno['points'][0][0], anno['points'][1][0],
            anno['points'][2][0], anno['points'][3][0])
        ymax = max(
            anno['points'][0][1], anno['points'][1][1],
            anno['points'][2][1], anno['points'][3][1])
        
        width = xmax - xmin
        height = ymax - ymin
        
        class_id = atoi[anno['label']]
            
        url = line['content']
        
        video_file_id = url.split('.')[-2].split('__')[-1]

        response = requests.get(url)
        if response.status_code == 200:
            with open(YOLO_OUTPATH/f'{video_file_id}.jpg', 'wb') as f:
                f.write(response.content)
                print('Saved', YOLO_OUTPATH/f'{video_file_id}.jpg')

        with open(YOLO_OUTPATH/f'{video_file_id}.txt', 'w') as fh:
            fh.write(f'{class_id} {xmin} {ymin} {width} {height}')
            print('Saved', YOLO_OUTPATH/f'{video_file_id}.txt')
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1367.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1367.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-262.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-262.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-504.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-504.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-2.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-2.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-699.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-699.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-114.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-114.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1213.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1213.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-316.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-316.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame
jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-652.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-134.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-134.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1019.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1019.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1025.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1025.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1186.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1186.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-726.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-726.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-901.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-901.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-929.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-929.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-530.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-530.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-524.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-524.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1345.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1345.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-283.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-283.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-17.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-17.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-254.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-254.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-8.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-8.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1147.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1147.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-917.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-917.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-491.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-491.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-453.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-453.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-490.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-490.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-889.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-889.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-862.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-862.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-16.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-16.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1344.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1344.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-251.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-251.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-912.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-912.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1195.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1195.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-721.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-721.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-899.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-899.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-324.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-324.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-132.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-132.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-898.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-898.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-640.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-640.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1037.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1037.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-708.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-708.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-244.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-244.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-293.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-293.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-11.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-11.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-534.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-534.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1169.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1169.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-130.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-130.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-656.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-656.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1237.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1237.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-483.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-483.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-694.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-694.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-723.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-723.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-938.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-938.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-910.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-910.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1168.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1168.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1342.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-1342.txt
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-284.jpg
# Saved ../data/yolo/_images_ZO8Npgp4xvw-frame-284.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-1081.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-1081.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-866.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-866.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-88.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-88.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-468.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-468.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-722.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-722.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-252.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-252.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-323.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-323.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-726.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-726.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-686.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-686.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-187.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-187.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-781.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-781.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-743.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-743.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-347.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-347.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-543.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-543.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-557.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-557.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-973.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-973.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-393.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-393.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-419.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-419.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-545.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-545.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-801.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-801.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-207.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-207.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-1016.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-1016.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-943.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-943.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-997.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-997.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-175.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-175.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-43.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-43.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-265.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-265.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-715.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-715.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-83.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-83.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-677.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-677.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-68.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-68.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-298.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-298.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-676.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-676.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-886.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-886.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-316.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-316.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-92.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-92.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-882.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-882.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-842.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-842.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-711.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-711.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-843.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-843.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-84.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-84.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-116.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-116.txt
# Saved ../data/yolo/5NbYyUlcHU-frame-102.jpg
# Saved ../data/yolo/5NbYyUlcHU-frame-102.txt

# %%
url
# Out:
# 'http://com.dataturks.a96-i23.open.s3.amazonaws.com/2c9fafb065aeb6960165db44c029022c/57b4baaa-bb31-4444-8c47-556de7f29246____5NbYyUlcHU__5NbYyUlcHU-frame-102.jpg'
