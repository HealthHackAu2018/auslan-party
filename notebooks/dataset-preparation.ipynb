# %% [markdown]
# # Dataset preparation

# %%
from pathlib import Path
import json
import requests

from shutil import copyfile
from tqdm import tqdm_notebook
import xmltodict
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ## Convert RectLabel format

# %%
alphabet = list('abcdefghijklmnopqrstuvwxyz') + ['na']

# %%
alphabet[:10]
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
atoi = {l: c for c, l in enumerate(alphabet)}

# %%
atoi['na']
# Out:
# 26

# %%
PATH = Path('../data/')

# %%
YOLO_OUTPATH = PATH/'yolo'
YOLO_OUTPATH.mkdir(exist_ok=True)

# %%
VID_IDS = ['33qU9tQlEa4', '6iP3g_qSf28', 'EBH3wdRtZyg', 'pAz_mIjHglw']

# %%
# keep_ids = set(['h', 'e', 'a', 'l', 't', 'h', 'h', 'a', 'c', 'k'])

# %%
for vid_id in tqdm_notebook(VID_IDS):
    VID_PATH = PATH/'annotations'/vid_id
    for item in VID_PATH.iterdir():
        with open(item) as fd:
            doc = xmltodict.parse(fd.read())
            
        if 'object' not in doc['annotation']:
            continue
            
        class_name = doc['annotation']['object']['name']
            
        img_width = int(doc['annotation']['size']['width'])
        img_height = int(doc['annotation']['size']['height'])
        
        bnd_box = doc['annotation']['object']['bndbox']
        
        x_min, y_min, x_max, y_max = (
            int(bnd_box['xmin']), int(bnd_box['ymin']), int(bnd_box['xmax']), int(bnd_box['ymax']))
        width = x_max - x_min
        height = y_max - y_min

        class_id = atoi[class_name]
        
        video_file_id = str(item).split('/')[-1].split('.')[-2]
        copyfile(PATH/f'images/{vid_id}/{video_file_id}.jpg', YOLO_OUTPATH/f'{video_file_id}.jpg')
        with open(YOLO_OUTPATH/f'{video_file_id}.txt', 'w') as fh:
            fh.write(f'{class_id} {x_min / img_width} {y_min / img_height} {width / img_width} {height / img_height}')
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))

# %% [markdown]
# ## Convert DataTurks format

# %%
JSON_VID_IDS = ['ZO8Npgp4xvw', '_5NbYyUlcHU', 'hzxjWuly0Go']

# %%
for vid_id in tqdm_notebook(JSON_VID_IDS):
    for line in open(PATH/'annotations'/f'{vid_id}.json'):
        line = json.loads(line)
        anno = line['annotation'][0]

        xmin = min(
            anno['points'][0][0], anno['points'][1][0], anno['points'][2][0], anno['points'][3][0])

        ymin = min(
            anno['points'][0][1], anno['points'][1][1],
            anno['points'][2][1], anno['points'][3][1])

        xmax = max(
            anno['points'][0][0], anno['points'][1][0],
            anno['points'][2][0], anno['points'][3][0])
        ymax = max(
            anno['points'][0][1], anno['points'][1][1],
            anno['points'][2][1], anno['points'][3][1])
        
        width = xmax - xmin
        height = ymax - ymin
        
        class_id = atoi[anno['label']]
            
        url = line['content']
        
        video_file_id = url.split('.')[-2].split('__')[-1]

        response = requests.get(url)
        if response.status_code == 200:
            with open(YOLO_OUTPATH/f'{video_file_id}.jpg', 'wb') as f:
                f.write(response.content)
                print('Saved', YOLO_OUTPATH/f'{video_file_id}.jpg')

        with open(YOLO_OUTPATH/f'{video_file_id}.txt', 'w') as fh:
            fh.write(f'{class_id} {xmin} {ymin} {width} {height}')
            print('Saved', YOLO_OUTPATH/f'{video_file_id}.txt')
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-256.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-256.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-257.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-257.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-26.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-26.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-267.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-267.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-272.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-272.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-277.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-277.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-278.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-278.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-284.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-284.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-290.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-290.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-298.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-298.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-299.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-299.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-3.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-3.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-302.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-302.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-304.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-304.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-305.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-305.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-311.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-311.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-313.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-313.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-316.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-316.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-317.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-317.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-319.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-319.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-321.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-321.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-327.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-327.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-329.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-329.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-33.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-33.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-331.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-331.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-332.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-332.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-337.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-337.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-354.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-354.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-355.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-355.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-358.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-358.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-359.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-359.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-36.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-36.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-365.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-365.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-366.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-366.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-369.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-369.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-372.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-372.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-377.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-377.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-38.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-38.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-385.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-385.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-388.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-388.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-390.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-390.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-393.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-393.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-396.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-396.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-397.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-397.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-399.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-399.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-402.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-402.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-409.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-409.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-410.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-410.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-416.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-416.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-417.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-417.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-421.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-421.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-422.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-422.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-424.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-424.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-43.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-43.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-433.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-433.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-448.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-448.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-449.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-449.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-450.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-450.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-46.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-46.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-463.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-463.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-465.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-465.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-468.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-468.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-469.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-469.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-470.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-470.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-475.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-475.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-477.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-477.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-484.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-484.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-485.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-485.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-489.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-489.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-491.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-491.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-492.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-492.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-494.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-494.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-50.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-50.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-507.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-507.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-512.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-512.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-520.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-520.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-528.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-528.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-53.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-53.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-533.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-533.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-535.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-535.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-542.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-542.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-55.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-55.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-56.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-56.txt
# Saved ../data/yolo/_hzxjWuly0Go-frame-562.jpg
# Saved ../data/yolo/_hzxjWuly0Go-frame-562.txt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-0c9ba51fe2d1> in <module>()
#       5
#       6         xmin = min(
# ----> 7             anno['points'][0][0], anno['points'][1][0], anno['points'][2][0], anno['points'][3][0])
#       8
#       9         ymin = min(
#
# IndexError: list index out of range

# %%
PATH = Path('../data')
(PATH/'yolo').mkdir(exist_ok=True)

# %%
alphabet = list('abcdefghijklmnopqrstuvwxyz') + ['na']
atoi = {l: c for c, l in enumerate(alphabet)}
itoa = {c: l for c, l in enumerate(alphabet)}

# %%
imgs = []
classes = []
bbs = []

from tqdm import tqdm
import math


for p in tqdm((PATH/'yolo').iterdir()):
    fn = p.parts[-1]

    if fn.endswith('.jpg'):
        imgs.append(fn)
        height, width, channels = plt.imread(p).shape

        labels = open(str(p).replace('.jpg', '.txt')).read().split()
        cls = itoa[int(labels[0])]
        xmin, ymin, bb_width, bb_height = labels[1:]
        
        bb_width_scaled = float(bb_width) * float(width)
        bb_height_scaled = float(bb_height) * float(height)
        
        # Have to unscale from Yolo format
        x = int(round(float(xmin) * float(width)))
        
        y = int(round(float(ymin) * float(height)))
                
        x2 = int(round(x + bb_width_scaled))
        y2 = int(round(y + bb_height_scaled))
            
        # Dunno why Fast.ai format has to be like this
        bb = f'{y} {x} {y2} {x2}'
        
        bbs.append(bb)
        classes.append(cls)
# Out:
# 2894it [00:35, 80.96it/s]

# %%
classes_df = pd.DataFrame({'image': imgs, 'class': classes})[['image', 'class']]
bbs_df = pd.DataFrame({'image': imgs, 'bb': bbs})[['image', 'bb']]

# %%
classes_df.to_csv(PATH/'train_classes.csv', index=False, columns=['image', 'class'])
bbs_df.to_csv(PATH/'train_bbs.csv', index=False, columns=['image', 'bb'])
